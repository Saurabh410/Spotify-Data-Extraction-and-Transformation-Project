# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager=SpotifyClientCredentials(client_id='b1cfc571ec7148ab905b65f59fbc4db6',client_secret='0259da710e2343e5ac8bf3dc77cbe393')

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_uri=playlist_link.split('/')[-1]

# %%
data=sp.playlist_tracks(playlist_uri)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0HiZ8fNXwJOQcrf5iflrdz'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Endless Summer Vacation'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-03-10'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 13

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={'album_id':album_id,
                  'album_name':album_name,
                  'album_release_date':album_release_date,
                  'album_total_tracks':album_total_tracks,
                  'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'album_name': 'Endless Summer Vacation',
#   'album_release_date': '2023-03-10',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'album_name': 'MAÑANA SERÁ BONITO',
#   'album_release_date': '2023-02-24',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'album_name': 'SOS',
#   'album_release_date': '2022-12-08',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '50uChhk7AKkzDKytDixjYW',
#   'album_name': 'RR',
#   'album_release_date': '2023-03-24',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/50uChhk7AKkzDKytDixjYW'},
#  {'album_id': '3Mm1P5CEEAiuJqBclr2EyU',
#   'album_name': 'Ella Baila Sola',
#   'album_release_date': '2023-03-16',
# ...

# %%
#

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp',
#   'artist_name': 'Shakira',
#   'external_url': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '7ltDVBr6mKbRvohxheJ9h1',
#   'artist_name': 'ROSALÍA',
#   'external_url': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
# ...

# %%
# data['items']

# %%
song_list=[]
for row in data['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['id']
    artist_id=row['track']['album']['artists'][0]['id']
    song_element={'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'song_url':song_url,'popularity':song_popularity,
                  'song_added':song_added,'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '4DHcnVTT87F0zZhRPYmZ3B',
#   'song_name': 'Flowers',
#   'duration_ms': 200600,
#   'song_url': 'https://open.spotify.com/track/4DHcnVTT87F0zZhRPYmZ3B',
#   'popularity': 88,
#   'song_added': '2023-04-01T10:17:21Z',
#   'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '0DWdj2oZMBFSzRsi2Cvfzf',
#   'song_name': 'TQG',
#   'duration_ms': 197933,
#   'song_url': 'https://open.spotify.com/track/0DWdj2oZMBFSzRsi2Cvfzf',
#   'popularity': 97,
#   'song_added': '2023-04-01T10:17:21Z',
#   'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'duration_ms': 153946,
#   'song_url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'popularity': 95,
#   'song_added': '2023-04-01T10:17:21Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '609E1JCInJncactoMmkDon',
# ...

# %%
album_df=pd.DataFrame(album_list)

# %%
album_df.head()
# Out:
#                  album_id               album_name album_release_date  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation         2023-03-10
# 1  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO         2023-02-24
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS         2022-12-08
# 3  50uChhk7AKkzDKytDixjYW                       RR         2023-03-24
# 4  3Mm1P5CEEAiuJqBclr2EyU          Ella Baila Sola         2023-03-16
#
#    album_total_tracks                                          album_url
# 0                  13  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1                  17  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2                  23  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3                   3  https://open.spotify.com/album/50uChhk7AKkzDKy...
# 4                   1  https://open.spotify.com/album/3Mm1P5CEEAiuJqB...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.head()
# Out:
#                  album_id               album_name album_release_date  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation         2023-03-10
# 1  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO         2023-02-24
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS         2022-12-08
# 3  50uChhk7AKkzDKytDixjYW                       RR         2023-03-24
# 4  3Mm1P5CEEAiuJqBclr2EyU          Ella Baila Sola         2023-03-16
#
#    album_total_tracks                                          album_url
# 0                  13  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1                  17  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2                  23  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3                   3  https://open.spotify.com/album/50uChhk7AKkzDKy...
# 4                   1  https://open.spotify.com/album/3Mm1P5CEEAiuJqB...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id  artist_name  \
# 0  5YGY8feqx7naU7z4HrwZM6  Miley Cyrus
# 1  790FomKkXshlbRYZFtlgla      KAROL G
# 2  0EmeFodog0BfCgMzAIvKQp      Shakira
# 3  7tYKF4w9nC0nq9CsPZTHyP          SZA
# 4  7ltDVBr6mKbRvohxheJ9h1      ROSALÍA
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 1  https://api.spotify.com/v1/artists/790FomKkXsh...
# 2  https://api.spotify.com/v1/artists/0EmeFodog0B...
# 3  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 4  https://api.spotify.com/v1/artists/7ltDVBr6mKb...

# %%
song_df=pd.DataFrame(song_list)

# %%
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  4DHcnVTT87F0zZhRPYmZ3B          Flowers       200600
# 1  0DWdj2oZMBFSzRsi2Cvfzf              TQG       197933
# 2  1Qrg8KqiBpW07V7PNxwwwL        Kill Bill       153946
# 3  609E1JCInJncactoMmkDon             BESO       194543
# 4  3dnP0JxCgygwQH9Gm7q7nb  Ella Baila Sola       165671
#
#                                             song_url  popularity  \
# 0  https://open.spotify.com/track/4DHcnVTT87F0zZh...          88
# 1  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          97
# 2  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          95
# 3  https://open.spotify.com/track/609E1JCInJncact...          89
# 4  https://open.spotify.com/track/3dnP0JxCgygwQH9...          91
#
#              song_added                album_id               artist_id
# 0  2023-04-01T10:17:21Z  0HiZ8fNXwJOQcrf5iflrdz  5YGY8feqx7naU7z4HrwZM6
# 1  2023-04-01T10:17:21Z  4kS7bSuU0Jm9LYMosFU2x5  790FomKkXshlbRYZFtlgla
# ...

# %%
album_df.head()
# Out:
#                  album_id               album_name album_release_date  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation         2023-03-10
# 1  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO         2023-02-24
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS         2022-12-08
# 3  50uChhk7AKkzDKytDixjYW                       RR         2023-03-24
# 4  3Mm1P5CEEAiuJqBclr2EyU          Ella Baila Sola         2023-03-16
#
#    album_total_tracks                                          album_url
# 0                  13  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1                  17  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2                  23  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3                   3  https://open.spotify.com/album/50uChhk7AKkzDKy...
# 4                   1  https://open.spotify.com/album/3Mm1P5CEEAiuJqB...

# %%
album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            48 non-null     object
#  1   album_name          48 non-null     object
#  2   album_release_date  48 non-null     datetime64[ns]
#  3   album_total_tracks  48 non-null     int64
#  4   album_url           48 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  4DHcnVTT87F0zZhRPYmZ3B          Flowers       200600
# 1  0DWdj2oZMBFSzRsi2Cvfzf              TQG       197933
# 2  1Qrg8KqiBpW07V7PNxwwwL        Kill Bill       153946
# 3  609E1JCInJncactoMmkDon             BESO       194543
# 4  3dnP0JxCgygwQH9Gm7q7nb  Ella Baila Sola       165671
#
#                                             song_url  popularity  \
# 0  https://open.spotify.com/track/4DHcnVTT87F0zZh...          88
# 1  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          97
# 2  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          95
# 3  https://open.spotify.com/track/609E1JCInJncact...          89
# 4  https://open.spotify.com/track/3dnP0JxCgygwQH9...          91
#
#                  song_added                album_id               artist_id
# 0 2023-04-01 10:17:21+00:00  0HiZ8fNXwJOQcrf5iflrdz  5YGY8feqx7naU7z4HrwZM6
# 1 2023-04-01 10:17:21+00:00  4kS7bSuU0Jm9LYMosFU2x5  790FomKkXshlbRYZFtlgla
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   song_url     50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
